# %%
# @title Notebook Settings

from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# @title Installation
# !pip install openai
# !pip install -U sentence-transformers
# !pip install PyPDF4
# !pip install msoffice2pdf
# !pip install pymupdf
# !!pip install "git+https://github.com/hwchase17/langchain.git"
# !pip install pinecone-client
# !pip install trafilatura
# !sudo apt install libreoffice -y
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.26.4.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 KB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from openai) (3.8.3)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai) (4.64.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.8.2)
# Building wheels for collected packages: openai
#   Building wheel for openai (pyproject.toml) ... done
#   Created wheel for openai: filename=openai-0.26.4-py3-none-any.whl size=67744 sha256=1049bea5c29f40c466c1553ef85e993956479c1c7385b443dd1a94a054e20f4d
#   Stored in directory: /root/.cache/pip/wheels/2b/d8/4e/268f029bd3277c1dd9e8781a0e0296e0a63822665bfa2429fc
# Successfully built openai
# Installing collected packages: openai
# Successfully installed openai-0.26.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (0.14.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.25.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=1e890c77d1760f9914b79e942f5cda341a9586ccc3d925a9ed61ee5462a12e7f
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.12.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.26.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF4
#   Downloading PyPDF4-1.27.0.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 KB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: PyPDF4
#   Building wheel for PyPDF4 (setup.py) ... done
#   Created wheel for PyPDF4: filename=PyPDF4-1.27.0-py3-none-any.whl size=61248 sha256=c7ba5e8616988ba7b97eadf546e674a904ca32725ed2a4989640754d8e68cccb
#   Stored in directory: /root/.cache/pip/wheels/f0/79/75/d130281ec9996a2551dbdd1836aa4beb376d53f8cdca49b4b0
# Successfully built PyPDF4
# Installing collected packages: PyPDF4
# Successfully installed PyPDF4-1.27.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting msoffice2pdf
#   Downloading msoffice2pdf-0.0.8-py3-none-any.whl (4.9 kB)
# Installing collected packages: msoffice2pdf
# Successfully installed msoffice2pdf-0.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymupdf
#   Downloading PyMuPDF-1.21.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 77.1 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.21.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pinecone-client
#   Downloading pinecone_client-2.1.0-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.6/170.6 KB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (4.4.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (4.64.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (2.25.1)
# Collecting loguru>=0.5.0
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (6.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from pinecone-client) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pinecone-client) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pinecone-client) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pinecone-client) (2022.12.7)
# Installing collected packages: loguru, pinecone-client
# Successfully installed loguru-0.6.0 pinecone-client-2.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting trafilatura
#   Downloading trafilatura-1.4.1-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.9 MB/s eta 0:00:00
# Collecting charset-normalizer>=3.0.1
#   Downloading charset_normalizer-3.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 KB 21.9 MB/s eta 0:00:00
# Collecting htmldate>=1.4.1
#   Downloading htmldate-1.4.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from trafilatura) (2022.12.7)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.8/dist-packages (from trafilatura) (4.9.2)
# Collecting urllib3<2,>=1.26
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.5 MB/s eta 0:00:00
# Collecting courlan>=0.8.3
#   Downloading courlan-0.8.3-py3-none-any.whl (34 kB)
# Collecting justext>=3.0.0
#   Downloading jusText-3.0.0-py2.py3-none-any.whl (837 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.8/837.8 KB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: langcodes>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from courlan>=0.8.3->trafilatura) (3.3.0)
# Collecting tld>=0.12.6
#   Downloading tld-0.12.7-py38-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 KB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.8/dist-packages (from htmldate>=1.4.1->trafilatura) (2.8.2)
# Collecting dateparser>=1.1.2
#   Downloading dateparser-1.1.7-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 KB 29.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.1->trafilatura) (2022.7.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.8/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.1->trafilatura) (2022.6.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.1->trafilatura) (1.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.2->htmldate>=1.4.1->trafilatura) (1.15.0)
# Installing collected packages: charset-normalizer, urllib3, tld, justext, dateparser, courlan, htmldate, trafilatura
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.1.1
#     Uninstalling charset-normalizer-2.1.1:
#       Successfully uninstalled charset-normalizer-2.1.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiohttp 3.8.3 requires charset-normalizer<3.0,>=2.0, but you have charset-normalizer 3.0.1 which is incompatible.
# Successfully installed charset-normalizer-3.0.1 courlan-0.8.3 dateparser-1.1.7 htmldate-1.4.1 justext-3.0.0 tld-0.12.7 trafilatura-1.4.1 urllib3-1.26.14
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   apparmor firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gstreamer1.0-gtk3 libabw-0.1-1 libapache-pom-java
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcmis-0.5-5v5 libcolamd2 libcommons-logging-java libcommons-parent-java
#   libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1
#   libexttextcat-2.0-0 libexttextcat-data libfbclient2 libfreehand-0.1-1
#   libgpgme11 libgpgmepp6 libhsqldb1.8.0-java libib-util libjsp-api-java
#   libjuh-java libjurt-java liblangtag-common liblangtag1 libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libneon27-gnutls
#   libodfgen-0.1-1 liborcus-0.15-0 libpagemaker-0.0-0 libraptor2-0 librasqal3
#   librdf0 libreoffice-base libreoffice-base-core libreoffice-base-drivers
#   libreoffice-calc libreoffice-common libreoffice-core libreoffice-draw
#   libreoffice-gnome libreoffice-gtk3 libreoffice-impress
#   libreoffice-java-common libreoffice-math libreoffice-nlpsolver
#   libreoffice-report-builder libreoffice-report-builder-bin
#   libreoffice-script-provider-bsh libreoffice-script-provider-js
#   libreoffice-script-provider-python libreoffice-sdbc-firebird
#   libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql libreoffice-sdbc-postgresql
#   libreoffice-style-colibre libreoffice-style-elementary
#   libreoffice-style-tango libreoffice-wiki-publisher libreoffice-writer
#   librevenge-0.0-0 libridl-java libservlet-api-java libservlet3.1-java
#   libsuitesparseconfig5 libtommath1 libuno-cppu3 libuno-cppuhelpergcc3-3
#   libuno-purpenvhelpergcc3-3 libuno-sal3 libuno-salhelpergcc3-3 libunoil-java
#   libunoloader-java libvisio-0.1-1 libwebsocket-api-java libwpd-0.10-10
#   libwpg-0.3-3 libwps-0.4-4 libxmlsec1 libxmlsec1-nss libyajl2 lp-solve
#   python3-uno uno-libs-private ure
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils firebird3.0-server firebird3.0-doc
#   libavalon-framework-java libcommons-logging-java-doc
#   libexcalibur-logkit-java liblog4j1.2-java java-virtual-machine
#   libhsqldb1.8.0-java-gcj raptor2-utils rasqal-utils librdf-storage-postgresql
#   librdf-storage-mysql librdf-storage-sqlite librdf-storage-virtuoso
#   redland-utils cups-bsd firefox-esr | thunderbird | firefox ghostscript gpa
#   hyphen-hyphenation-patterns imagemagick | graphicsmagick-imagemagick-compat
#   libreoffice-grammarcheck libreoffice-help libreoffice-l10n
#   libreoffice-librelogo myspell-dictionary mythes-thesaurus
#   openclipart2-libreoffice | openclipart-libreoffice pstoedit unixodbc
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-plugins-ugly gstreamer1.0-plugins-bad gstreamer1.0-libav
#   libsane libofficebean-java libjtds-java libsqliteodbc | tdsodbc
#   | odbc-mdbtools libreoffice-evolution seahorse libreofficekit-data bluez
#   default-mysql-server | virtual-mysql-server postgresql tango-icon-theme
#   mediawiki
# The following NEW packages will be installed:
#   apparmor firebird3.0-common firebird3.0-common-doc firebird3.0-server-core
#   firebird3.0-utils fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra fonts-liberation2
#   fonts-linuxlibertine fonts-noto-core fonts-noto-extra fonts-noto-mono
#   fonts-noto-ui-core fonts-opensymbol fonts-sil-gentium
#   fonts-sil-gentium-basic gstreamer1.0-gtk3 libabw-0.1-1 libapache-pom-java
#   libbsh-java libcdr-0.1-1 libclucene-contribs1v5 libclucene-core1v5
#   libcmis-0.5-5v5 libcolamd2 libcommons-logging-java libcommons-parent-java
#   libe-book-0.1-1 libel-api-java libeot0 libepubgen-0.1-1 libetonyek-0.1-1
#   libexttextcat-2.0-0 libexttextcat-data libfbclient2 libfreehand-0.1-1
#   libgpgme11 libgpgmepp6 libhsqldb1.8.0-java libib-util libjsp-api-java
#   libjuh-java libjurt-java liblangtag-common liblangtag1 libmhash2
#   libmspub-0.1-1 libmwaw-0.3-3 libmythes-1.2-0 libneon27-gnutls
#   libodfgen-0.1-1 liborcus-0.15-0 libpagemaker-0.0-0 libraptor2-0 librasqal3
#   librdf0 libreoffice libreoffice-base libreoffice-base-core
#   libreoffice-base-drivers libreoffice-calc libreoffice-common
#   libreoffice-core libreoffice-draw libreoffice-gnome libreoffice-gtk3
#   libreoffice-impress libreoffice-java-common libreoffice-math
#   libreoffice-nlpsolver libreoffice-report-builder
#   libreoffice-report-builder-bin libreoffice-script-provider-bsh
#   libreoffice-script-provider-js libreoffice-script-provider-python
#   libreoffice-sdbc-firebird libreoffice-sdbc-hsqldb libreoffice-sdbc-mysql
#   libreoffice-sdbc-postgresql libreoffice-style-colibre
#   libreoffice-style-elementary libreoffice-style-tango
#   libreoffice-wiki-publisher libreoffice-writer librevenge-0.0-0 libridl-java
#   libservlet-api-java libservlet3.1-java libsuitesparseconfig5 libtommath1
#   libuno-cppu3 libuno-cppuhelpergcc3-3 libuno-purpenvhelpergcc3-3 libuno-sal3
#   libuno-salhelpergcc3-3 libunoil-java libunoloader-java libvisio-0.1-1
#   libwebsocket-api-java libwpd-0.10-10 libwpg-0.3-3 libwps-0.4-4 libxmlsec1
#   libxmlsec1-nss libyajl2 lp-solve python3-uno uno-libs-private ure
# 0 upgraded, 112 newly installed, 0 to remove and 27 not upgraded.
# Need to get 203 MB of archives.
# After this operation, 799 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-opensymbol all 2:102.11+LibO6.4.7-0ubuntu0.20.04.6 [93.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-style-colibre all 1:6.4.7-0ubuntu0.20.04.6 [1,180 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-style-tango all 1:6.4.7-0ubuntu0.20.04.6 [1,248 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuno-sal3 amd64 1:6.4.7-0ubuntu0.20.04.6 [149 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuno-salhelpergcc3-3 amd64 1:6.4.7-0ubuntu0.20.04.6 [16.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuno-cppu3 amd64 1:6.4.7-0ubuntu0.20.04.6 [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 uno-libs-private amd64 1:6.4.7-0ubuntu0.20.04.6 [226 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 liblangtag-common all 0.6.3-1 [174 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 liblangtag1 amd64 0.6.3-1 [49.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuno-cppuhelpergcc3-3 amd64 1:6.4.7-0ubuntu0.20.04.6 [273 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuno-purpenvhelpergcc3-3 amd64 1:6.4.7-0ubuntu0.20.04.6 [15.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 ure amd64 1:6.4.7-0ubuntu0.20.04.6 [1,224 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-common all 1:6.4.7-0ubuntu0.20.04.6 [23.5 MB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libclucene-core1v5 amd64 2.3.3.4+dfsg-1build1 [485 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libclucene-contribs1v5 amd64 2.3.3.4+dfsg-1build1 [81.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libcmis-0.5-5v5 amd64 0.5.2-1ubuntu1 [438 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libeot0 amd64 0.01-5 [26.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libexttextcat-data all 3.4.5-1 [162 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libexttextcat-2.0-0 amd64 3.4.5-1 [13.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libgpgme11 amd64 1.13.1-7ubuntu2 [121 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libgpgmepp6 amd64 1.13.1-7ubuntu2 [101 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libmythes-1.2-0 amd64 2:1.2.4-3build1 [8,552 B]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libneon27-gnutls amd64 0.30.2-4 [67.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 liborcus-0.15-0 amd64 0.15.3-3build2 [441 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu5 [202 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmlsec1 amd64 1.2.28-2 [127 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmlsec1-nss amd64 1.2.28-2 [61.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libyajl2 amd64 2.1.0-3 [20.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libraptor2-0 amd64 2.0.15-0ubuntu1.20.04.1 [158 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libmhash2 amd64 0.9.9.9-8 [88.8 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 librasqal3 amd64 0.9.33-0.1 [173 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 librdf0 amd64 1.0.17-1.1ubuntu1 [96.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-core amd64 1:6.4.7-0ubuntu0.20.04.6 [31.6 MB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-base-core amd64 1:6.4.7-0ubuntu0.20.04.6 [773 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-base-drivers amd64 1:6.4.7-0ubuntu0.20.04.6 [511 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-base amd64 1:6.4.7-0ubuntu0.20.04.6 [1,462 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apparmor amd64 2.13.3-7ubuntu5.1 [494 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/universe amd64 firebird3.0-common-doc all 3.0.5.33220.ds4-1build2 [25.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/universe amd64 firebird3.0-common all 3.0.5.33220.ds4-1build2 [14.9 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libtommath1 amd64 1.2.0-3 [53.0 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfbclient2 amd64 3.0.5.33220.ds4-1build2 [557 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 libib-util amd64 3.0.5.33220.ds4-1build2 [3,324 B]
# Get:43 http://archive.ubuntu.com/ubuntu focal/universe amd64 firebird3.0-server-core amd64 3.0.5.33220.ds4-1build2 [2,599 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/universe amd64 firebird3.0-utils amd64 3.0.5.33220.ds4-1build2 [853 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-crosextra-caladea all 20130214-2 [82.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-crosextra-carlito all 20130920-1 [742 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-dejavu all 2.37-1 [3,130 B]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-liberation2 all 2.1.0-1 [1,458 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-linuxlibertine all 5.3.0-4 [1,627 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-core all 20200323-1build1~ubuntu20.04.1 [10.9 MB]
# Get:53 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 fonts-noto-extra all 20200323-1build1~ubuntu20.04.1 [68.8 MB]
# Get:54 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-mono all 20200323-1build1~ubuntu20.04.1 [80.6 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-ui-core all 20200323-1build1~ubuntu20.04.1 [1,326 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-sil-gentium all 20081126:1.03-2 [245 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-sil-gentium-basic all 1.102-1 [384 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-gtk3 amd64 1.16.3-0ubuntu1.1 [69.4 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/main amd64 libabw-0.1-1 amd64 0.1.3-1build1 [114 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:61 http://archive.ubuntu.com/ubuntu focal/universe amd64 libbsh-java all 2.0b4-20 [289 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/main amd64 libcdr-0.1-1 amd64 0.1.6-1build2 [342 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/main amd64 libsuitesparseconfig5 amd64 1:5.7.1+dfsg-2 [9,736 B]
# Get:64 http://archive.ubuntu.com/ubuntu focal/main amd64 libcolamd2 amd64 1:5.7.1+dfsg-2 [17.0 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcommons-logging-java all 1.2-2 [60.3 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 libe-book-0.1-1 amd64 0.1.3-1build3 [154 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal/universe amd64 libel-api-java all 3.0.0-2 [64.8 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 libepubgen-0.1-1 amd64 0.1.1-1ubuntu2 [138 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 libetonyek-0.1-1 amd64 0.1.9-3 [665 kB]
# Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 libfreehand-0.1-1 amd64 0.1.2-2ubuntu1 [246 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal/universe amd64 libservlet-api-java all 4.0.1-2 [81.0 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal/universe amd64 libjsp-api-java all 2.3.4-2 [53.6 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwebsocket-api-java all 1.1-1 [39.9 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/universe amd64 libservlet3.1-java all 1:4.0.1-2 [9,276 B]
# Get:76 http://archive.ubuntu.com/ubuntu focal/universe amd64 libhsqldb1.8.0-java all 1.8.0.10+dfsg-10 [770 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjuh-java all 1:6.4.7-0ubuntu0.20.04.6 [57.7 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjurt-java all 1:6.4.7-0ubuntu0.20.04.6 [105 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal/main amd64 libmspub-0.1-1 amd64 0.1.4-1build3 [135 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/main amd64 libmwaw-0.3-3 amd64 0.3.15-2build1 [2,225 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 libodfgen-0.1-1 amd64 0.1.7-1ubuntu2 [279 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 libpagemaker-0.0-0 amd64 0.0.4-1build1 [62.0 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/main amd64 lp-solve amd64 5.5.0.15-4build1 [283 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/main amd64 libwps-0.4-4 amd64 0.4.10-1build1 [795 kB]
# Get:85 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-calc amd64 1:6.4.7-0ubuntu0.20.04.6 [7,200 kB]
# Get:86 http://archive.ubuntu.com/ubuntu focal/main amd64 libvisio-0.1-1 amd64 0.1.7-1build2 [215 kB]
# Get:87 http://archive.ubuntu.com/ubuntu focal/main amd64 libwpd-0.10-10 amd64 0.10.3-1build1 [179 kB]
# Get:88 http://archive.ubuntu.com/ubuntu focal/main amd64 libwpg-0.3-3 amd64 0.3.3-1build1 [46.8 kB]
# Get:89 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-draw amd64 1:6.4.7-0ubuntu0.20.04.6 [2,850 kB]
# Get:90 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-impress amd64 1:6.4.7-0ubuntu0.20.04.6 [1,072 kB]
# Get:91 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-math amd64 1:6.4.7-0ubuntu0.20.04.6 [402 kB]
# Get:92 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-report-builder-bin amd64 1:6.4.7-0ubuntu0.20.04.6 [790 kB]
# Get:93 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-writer amd64 1:6.4.7-0ubuntu0.20.04.6 [8,597 kB]
# Get:94 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-uno amd64 1:6.4.7-0ubuntu0.20.04.6 [126 kB]
# Get:95 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice amd64 1:6.4.7-0ubuntu0.20.04.6 [12.6 kB]
# Get:96 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-gnome amd64 1:6.4.7-0ubuntu0.20.04.6 [54.6 kB]
# Get:97 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-gtk3 amd64 1:6.4.7-0ubuntu0.20.04.6 [400 kB]
# Get:98 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libridl-java all 1:6.4.7-0ubuntu0.20.04.6 [196 kB]
# Get:99 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libunoil-java all 1:6.4.7-0ubuntu0.20.04.6 [1,262 kB]
# Get:100 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libunoloader-java all 1:6.4.7-0ubuntu0.20.04.6 [12.3 kB]
# Get:101 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-java-common all 1:6.4.7-0ubuntu0.20.04.6 [624 kB]
# Get:102 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-report-builder all 1:6.4.7-0ubuntu0.20.04.6 [2,119 kB]
# Get:103 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-script-provider-bsh all 1:6.4.7-0ubuntu0.20.04.6 [39.5 kB]
# Get:104 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-script-provider-js all 1:6.4.7-0ubuntu0.20.04.6 [650 kB]
# Get:105 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-script-provider-python all 1:6.4.7-0ubuntu0.20.04.6 [16.3 kB]
# Get:106 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-sdbc-firebird amd64 1:6.4.7-0ubuntu0.20.04.6 [132 kB]
# Get:107 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-sdbc-hsqldb amd64 1:6.4.7-0ubuntu0.20.04.6 [113 kB]
# Get:108 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-sdbc-mysql amd64 1:6.4.7-0ubuntu0.20.04.6 [101 kB]
# Get:109 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-sdbc-postgresql amd64 1:6.4.7-0ubuntu0.20.04.6 [228 kB]
# Get:110 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-style-elementary all 1:6.4.7-0ubuntu0.20.04.6 [7,310 kB]
# Get:111 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libreoffice-wiki-publisher all 1.2.0+LibO6.4.7-0ubuntu0.20.04.6 [1,394 kB]
# Get:112 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libreoffice-nlpsolver all 0.9+LibO6.4.7-0ubuntu0.20.04.6 [682 kB]
# Fetched 203 MB in 9s (23.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 112.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 129496 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.11+LibO6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking fonts-opensymbol (2:102.11+LibO6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-style-colibre (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-style-tango.
# Preparing to unpack .../002-libreoffice-style-tango_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-style-tango (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../003-libuno-sal3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libuno-sal3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../004-libuno-salhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../005-libuno-cppu3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libuno-cppu3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../006-uno-libs-private_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking uno-libs-private (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../007-liblangtag-common_0.6.3-1_all.deb ...
# Unpacking liblangtag-common (0.6.3-1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../008-liblangtag1_0.6.3-1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../009-libuno-cppuhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../010-libuno-purpenvhelpergcc3-3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../011-ure_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking ure (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../012-libreoffice-common_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-common (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../013-libclucene-core1v5_2.3.3.4+dfsg-1build1_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../014-libclucene-contribs1v5_2.3.3.4+dfsg-1build1_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Selecting previously unselected package libcmis-0.5-5v5.
# Preparing to unpack .../015-libcmis-0.5-5v5_0.5.2-1ubuntu1_amd64.deb ...
# Unpacking libcmis-0.5-5v5 (0.5.2-1ubuntu1) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../016-libeot0_0.01-5_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../017-libexttextcat-data_3.4.5-1_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../018-libexttextcat-2.0-0_3.4.5-1_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../019-libgpgme11_1.13.1-7ubuntu2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.13.1-7ubuntu2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../020-libgpgmepp6_1.13.1-7ubuntu2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.13.1-7ubuntu2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../021-libmythes-1.2-0_2%3a1.2.4-3build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-3build1) ...
# Selecting previously unselected package libneon27-gnutls:amd64.
# Preparing to unpack .../022-libneon27-gnutls_0.30.2-4_amd64.deb ...
# Unpacking libneon27-gnutls:amd64 (0.30.2-4) ...
# Selecting previously unselected package liborcus-0.15-0:amd64.
# Preparing to unpack .../023-liborcus-0.15-0_0.15.3-3build2_amd64.deb ...
# Unpacking liborcus-0.15-0:amd64 (0.15.3-3build2) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../024-librevenge-0.0-0_0.0.4-6ubuntu5_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu5) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../025-libxmlsec1_1.2.28-2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.28-2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../026-libxmlsec1-nss_1.2.28-2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.28-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../027-libyajl2_2.1.0-3_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../028-libraptor2-0_2.0.15-0ubuntu1.20.04.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu1.20.04.1) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../029-libmhash2_0.9.9.9-8_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-8) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../030-librasqal3_0.9.33-0.1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../031-librdf0_1.0.17-1.1ubuntu1_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu1) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../032-libreoffice-core_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-core (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../033-libreoffice-base-core_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-base-core (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../034-libreoffice-base-drivers_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../035-libreoffice-base_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../036-apparmor_2.13.3-7ubuntu5.1_amd64.deb ...
# Unpacking apparmor (2.13.3-7ubuntu5.1) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../037-firebird3.0-common-doc_3.0.5.33220.ds4-1build2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../038-firebird3.0-common_3.0.5.33220.ds4-1build2_all.deb ...
# Unpacking firebird3.0-common (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../039-libtommath1_1.2.0-3_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-3) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../040-libfbclient2_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../041-libib-util_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../042-firebird3.0-server-core_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../043-firebird3.0-utils_3.0.5.33220.ds4-1build2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.5.33220.ds4-1build2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../044-fonts-crosextra-caladea_20130214-2_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../045-fonts-crosextra-carlito_20130920-1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../046-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../047-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../048-fonts-dejavu_2.37-1_all.deb ...
# Unpacking fonts-dejavu (2.37-1) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../049-fonts-liberation2_2.1.0-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.0-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../050-fonts-linuxlibertine_5.3.0-4_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-4) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../051-fonts-noto-core_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-core (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../052-fonts-noto-extra_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-extra (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../053-fonts-noto-mono_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../054-fonts-noto-ui-core_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-ui-core (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../055-fonts-sil-gentium_20081126%3a1.03-2_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-2) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../056-fonts-sil-gentium-basic_1.102-1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../057-gstreamer1.0-gtk3_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../058-libabw-0.1-1_0.1.3-1build1_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build1) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../059-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../060-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../061-libcdr-0.1-1_0.1.6-1build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-1build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../062-libsuitesparseconfig5_1%3a5.7.1+dfsg-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.7.1+dfsg-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../063-libcolamd2_1%3a5.7.1+dfsg-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.7.1+dfsg-2) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../064-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../065-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../066-libe-book-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../067-libel-api-java_3.0.0-2_all.deb ...
# Unpacking libel-api-java (3.0.0-2) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../068-libepubgen-0.1-1_0.1.1-1ubuntu2_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu2) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../069-libetonyek-0.1-1_0.1.9-3_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.9-3) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../070-libfreehand-0.1-1_0.1.2-2ubuntu1_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-2ubuntu1) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../071-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../072-libjsp-api-java_2.3.4-2_all.deb ...
# Unpacking libjsp-api-java (2.3.4-2) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../073-libwebsocket-api-java_1.1-1_all.deb ...
# Unpacking libwebsocket-api-java (1.1-1) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../074-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../075-libhsqldb1.8.0-java_1.8.0.10+dfsg-10_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-10) ...
# Selecting previously unselected package libjuh-java.
# Preparing to unpack .../076-libjuh-java_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libjuh-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libjurt-java.
# Preparing to unpack .../077-libjurt-java_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libjurt-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../078-libmspub-0.1-1_0.1.4-1build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-1build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../079-libmwaw-0.3-3_0.3.15-2build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.15-2build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../080-libodfgen-0.1-1_0.1.7-1ubuntu2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.7-1ubuntu2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../081-libpagemaker-0.0-0_0.0.4-1build1_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build1) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../082-lp-solve_5.5.0.15-4build1_amd64.deb ...
# Unpacking lp-solve (5.5.0.15-4build1) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../083-libwps-0.4-4_0.4.10-1build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.10-1build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../084-libreoffice-calc_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-calc (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../085-libvisio-0.1-1_0.1.7-1build2_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build2) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../086-libwpd-0.10-10_0.10.3-1build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-1build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../087-libwpg-0.3-3_0.3.3-1build1_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build1) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../088-libreoffice-draw_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-draw (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../089-libreoffice-impress_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-impress (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../090-libreoffice-math_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-math (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../091-libreoffice-report-builder-bin_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../092-libreoffice-writer_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-writer (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../093-python3-uno_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking python3-uno (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../094-libreoffice_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../095-libreoffice-gnome_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-gnome (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../096-libreoffice-gtk3_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libridl-java.
# Preparing to unpack .../097-libridl-java_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libridl-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libunoil-java.
# Preparing to unpack .../098-libunoil-java_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libunoil-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../099-libunoloader-java_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libunoloader-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../100-libreoffice-java-common_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-java-common (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../101-libreoffice-report-builder_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-report-builder (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../102-libreoffice-script-provider-bsh_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../103-libreoffice-script-provider-js_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-script-provider-js (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../104-libreoffice-script-provider-python_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-script-provider-python (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../105-libreoffice-sdbc-firebird_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../106-libreoffice-sdbc-hsqldb_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../107-libreoffice-sdbc-mysql_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../108-libreoffice-sdbc-postgresql_1%3a6.4.7-0ubuntu0.20.04.6_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../109-libreoffice-style-elementary_1%3a6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-style-elementary (1:6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../110-libreoffice-wiki-publisher_1.2.0+LibO6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO6.4.7-0ubuntu0.20.04.6) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../111-libreoffice-nlpsolver_0.9+LibO6.4.7-0ubuntu0.20.04.6_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO6.4.7-0ubuntu0.20.04.6) ...
# Setting up fonts-sil-gentium-basic (1.102-1) ...
# Setting up fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Setting up liborcus-0.15-0:amd64 (0.15.3-3build2) ...
# Setting up libtommath1:amd64 (1.2.0-3) ...
# Setting up fonts-noto-extra (20200323-1build1~ubuntu20.04.1) ...
# Setting up libunoil-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libyajl2:amd64 (2.1.0-3) ...
# Setting up libuno-sal3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libel-api-java (3.0.0-2) ...
# Setting up libcmis-0.5-5v5 (0.5.2-1ubuntu1) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libreoffice-style-tango (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libeot0:amd64 (0.01-5) ...
# Setting up libgpgme11:amd64 (1.13.1-7ubuntu2) ...
# Setting up firebird3.0-common-doc (3.0.5.33220.ds4-1build2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu5) ...
# Setting up fonts-crosextra-carlito (20130920-1) ...
# Setting up firebird3.0-common (3.0.5.33220.ds4-1build2) ...
# Setting up apparmor (2.13.3-7ubuntu5.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up fonts-sil-gentium (20081126:1.03-2) ...
# Setting up libreoffice-style-colibre (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up fonts-liberation2 (2.1.0-1) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up libwebsocket-api-java (1.1-1) ...
# Setting up libneon27-gnutls:amd64 (0.30.2-4) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libfreehand-0.1-1 (0.1.2-2ubuntu1) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Setting up fonts-linuxlibertine (5.3.0-4) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-2) ...
# Setting up libmhash2:amd64 (0.9.9.9-8) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-3build1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up libexttextcat-data (3.4.5-1) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build1) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu2) ...
# Setting up fonts-crosextra-caladea (20130214-2) ...
# Setting up liblangtag-common (0.6.3-1) ...
# Setting up libib-util:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up libunoloader-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up fonts-noto-ui-core (20200323-1build1~ubuntu20.04.1) ...
# Setting up libxmlsec1:amd64 (1.2.28-2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-1build1) ...
# Setting up fonts-noto-core (20200323-1build1~ubuntu20.04.1) ...
# Setting up libridl-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.7.1+dfsg-2) ...
# Setting up fonts-opensymbol (2:102.11+LibO6.4.7-0ubuntu0.20.04.6) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.7-1ubuntu2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build2) ...
# Setting up libreoffice-style-elementary (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up fonts-dejavu (2.37-1) ...
# Setting up libwps-0.4-4:amd64 (0.4.10-1build1) ...
# Setting up libcolamd2:amd64 (1:5.7.1+dfsg-2) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1) ...
# Setting up libgpgmepp6:amd64 (1.13.1-7ubuntu2) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-1build3) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu1.20.04.1) ...
# Setting up lp-solve (5.5.0.15-4build1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build1) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.15-2build1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-1build2) ...
# Setting up liblangtag1:amd64 (0.6.3-1) ...
# Setting up libfbclient2:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up firebird3.0-utils (3.0.5.33220.ds4-1build2) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-10) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1build1) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build1) ...
# Setting up libxmlsec1-nss:amd64 (1.2.28-2) ...
# Setting up firebird3.0-server-core:amd64 (3.0.5.33220.ds4-1build2) ...
# Setting up librasqal3:amd64 (0.9.33-0.1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.9-3) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu1) ...
# Setting up libuno-salhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libuno-cppu3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up uno-libs-private (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libuno-cppuhelpergcc3-3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up ure (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libjurt-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-common (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libjuh-java (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-core (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-math (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-gtk3 (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-sdbc-postgresql (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-draw (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-java-common (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-base-drivers (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-sdbc-firebird (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-sdbc-mysql (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-gnome (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-impress (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-base-core (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up python3-uno (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-script-provider-bsh (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-script-provider-js (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-calc (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-base (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-sdbc-hsqldb (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-writer (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-script-provider-python (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-nlpsolver (0.9+LibO6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-report-builder-bin (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice (1:6.4.7-0ubuntu0.20.04.6) ...
# Setting up libreoffice-report-builder (1:6.4.7-0ubuntu0.20.04.6) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for systemd (245.4-4ubuntu3.19) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...

# %%
# @title Importing libraries

import re
import os
import fitz
import json
import shutil
import PyPDF4
import openai
import requests
import pinecone
import itertools
import trafilatura
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from msoffice2pdf import convert
from urllib.parse import urljoin
from langchain.llms import OpenAI
from sentence_transformers import util
from langchain.agents import load_tools
from langchain.vectorstores import Pinecone
from langchain.agents import initialize_agent
from PyPDF4 import PdfFileReader, PdfFileWriter
from langchain.embeddings import OpenAIEmbeddings
from langchain import OpenAI, LLMChain, PromptTemplate
from langchain import PromptTemplate, OpenAI, LLMChain
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains.conversation.memory import ConversationalBufferWindowMemory
from langchain.chains.conversation.memory import ConversationBufferMemory, ConversationSummaryBufferMemory
from langchain.embeddings import CohereEmbeddings, OpenAIEmbeddings, HuggingFaceEmbeddings, TensorflowHubEmbeddings
# Mount google drive where PDF file is uploaded [PATH:'/content/drive/MyDrive/sample/']
from google.colab import drive
drive.mount('/content/drive')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Mounted at /content/drive

# %%
# @title Get all URLs list from the URL
def get_url_list(path, url_type:bool):
  page = requests.get(path)
  soup = BeautifulSoup(page.text, 'html.parser')
  links_list = []
  try:
    if url_type is True:
      data = soup.find_all('a',{'class':'dds__link dds__link--standalone removeunderline'})
    elif url_type is False:
      data = soup.find_all('a',{'class':'dds__link dds__link--standalone'})
  except: 
    print('Provide url_type type')
  
  for link in data:
      full_link = urljoin(path, str(link.get('href')))
      r = requests.get(full_link)
      if r.status_code == 200 and ' ' not in full_link:
        links_list.append(full_link)

  return list(np.unique(links_list))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Text Extractor function that extracts text from specific Link

def extract_text_from_url(article_url: str):
    try:
      headers = {
          "accept": "application/json",
          "X-API-KEY": EXTRACT_API_KEY,
          "Content-Type": "application/json",
      }

      data = json.dumps({
          "url": article_url
      })

      response = requests.post("https://extract.tldrthis.com/v1/extract-article/", headers=headers, data=data, timeout=30)
      response.raise_for_status()
      if response.status_code == 200:
        article_metadata = response.json()
  
        article_metadata["article_text"] = re.sub(r'\n\s*\n', '\n\n', article_metadata["article_text"])
        return article_metadata
    except requests.exceptions.RequestException as err:
      print(err)
      return False
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Function to Extract Text from every link of Company Docs url list

def get_text_from_url_list(links_list):
  webpages_text = []
  for link in links_list:
    downloaded = trafilatura.fetch_url(link)
    extracted_text = trafilatura.extract(downloaded)
    if "video" not in link:
      webpages_text.append(extracted_text)
    print(f'Text from {link} Extracted')
  
  return webpages_text
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Function to Extract Text from URLs (calling get_text_from_url_list for getting webpage text). (change url page ranges, current: 20-25)

def extract_text_from_links(url):
  url_list = get_url_list(url, True) # Extract Every link of Docs 
  sub_links = []
  for link in url_list:
    sub_link = get_url_list(link, False)
    sub_links.append(sub_link)

  sub_links = list(itertools.chain.from_iterable(sub_links))
  all_links = url_list + sub_links
  print(f'Total {len(all_links)} Links Found')


  all_links = all_links[1:3]     # Selecting minimum pages including maximum informations to reduce excessive embedding of Text 
  extracted_text = get_text_from_url_list(all_links)                  # Extracted Text from Every link of Docs

  return extracted_text
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
from PyPDF4.generic import encode_pdfdocencoding
#@title Function to Extract Text from the PDF

def extract_text_from_pdf(file_path):
  pdf_document = fitz.open(file_path)
  num_pages = pdf_document.page_count
  text = []
  for i in range(num_pages):
      page = pdf_document[i]
      page_text = page.get_text()
      text.append(page_text.replace('\xa0', '').replace('\n', '').replace('\\', '').replace('\uf0d8', '').replace('\uf071', '').replace('\uf0a7', '').replace('\uf0fc', ''))
  pdf_document.close()
  return text
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Function to Get Text Extract from PDF, DOCX by every page

def extract_text_by_pages(path):
  shutil.copy(path, '/content/')
  splitted_path = path.split('.')
  file_name = splitted_path[0].split('/')[-1]
  file_type = splitted_path[1]

  generated_pdf = None
  new_path = f'/content/{file_name}.{file_type}'
  print(f'File moved, PATH : {new_path}')
  if file_type != 'pdf':
    output = convert(source=new_path, output_dir='/content/', soft=0)
    print(output)
    generated_pdf = output

  if generated_pdf: 
    text = extract_text_from_pdf(generated_pdf)
    text = [x.strip() for x in text]
    
  else:
    text = extract_text_from_pdf(new_path)
    text = [x.strip() for x in text]

  # !rm {new_path}
  if generated_pdf:
    # !rm {generated_pdf}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Function to create and store embeddings into the Pinecone.

def store_embeddings(texts, index_name, creator="huggingface"):
  if creator == "cohere":
    # embeddings = CohereEmbeddings(cohere_api_key= cohere_api_key)   
    pass
  elif creator == "huggingface":
    embeddings = HuggingFaceEmbeddings()
  elif creator == "tensorflow":
    embeddings = TensorflowHubEmbeddings()
  else:
    embeddings = OpenAIEmbeddings()

  pinecone.init(api_key=os.environ["PINECONE_API_KEY"], environment=os.environ["PINECONE_REGION"])
  if index_name not in pinecone.list_indexes():
      pinecone.create_index(
          index_name,
          dimension=768,
          metric="cosine"
      )
  text_embeddings = Pinecone.from_texts(texts=texts, embedding=embeddings, index_name=index_name)
  return text_embeddings
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Function to get text from the file or the docs url.

def text_embeddings(path, index_name):
  if path[:4] == "http":
    texts = extract_text_from_links(path)
  else:
    texts = extract_text_from_pdf(path)
  splitted_texts = []
  text_embeddings = []
  for text in texts:
    text_splitter = CharacterTextSplitter(
      separator = "\n",
      chunk_size = 1500,
      chunk_overlap  = 200,
      length_function = len,
    )
    text = str(text).replace("[", "").replace("]", "")
    splitted_text = text_splitter.split_text(text)
    splitted_texts.extend(splitted_text)
    text_embedding = store_embeddings(splitted_text, index_name)
    text_embeddings.extend(splitted_text)
  return text_embeddings
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Construct the prompt containing all the required information.

def construct_prompt(web_text, company_name):
  prompt = f"""You are talking to Ayurveda SupportBot, a Chatbot! Ayurveda SupportBot is designed specifically for the enterprise environment, providing accurate and reliable information to employees and stakeholders. By using only the given SPECIFIC INFORMATION, Ayurveda SupportBot is able to provide answers to questions related to the company.\n\nRead the following SPECIFIC INFORMATION carefully, then answer the request based on the given SPECIFIC INFORMATION. Be sure to provide a lengthy, detailed response for each request. If the user asks for multiple requests, then answer all the requests. Do not mention 'SPECIFIC INFORMATION' words in the generated answer. Do not include any information outside the given SPECIFIC INFORMATION. Be sure that if related information regarding the Question is not found in SPECIFIC INFORMATION, then respond only with the below Format. Do not add any additional words in Format.\nFormat:\n'''\nSorry, I can't help. Reach out to our Customer Support Team.\n'''\n\nSPECIFIC INFORMATION:
  \n
  {web_text}
  ###

  Company Name: {company_name}
  """
  return prompt
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title Gives the final answer (memory functionality is implemented)

def give_answer(docs, question, complex_answer = 0):
  text = docs[0].page_content
  text = str(text)[:7000].replace("[", "").replace("]", "")
  template = construct_prompt(text, "Ayurveda")
  template += """
  {chat_history}
  Human: {question}
  AI:
  """
  prompt_template = PromptTemplate(input_variables=["chat_history","question"], template=template)
  memory = ConversationalBufferWindowMemory(k=4, memory_key="chat_history")
  llm_chain = LLMChain(
      llm=OpenAI(max_tokens=300),     # max_tokens defines how long each answer will be generated
      prompt=prompt_template,
      verbose=True,
      memory=memory,
  )
  result = llm_chain.predict(question=question)
  print(result)
  while question.lower() != "stop":
    question = input("Enter your question to continue OR 'stop' to exit: ")
    if question.lower() != "stop":
      result = llm_chain.predict(question=question)
      print(result)
  return result
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title A wrapper around functions.

class ChatBot():
  def __init__(self, path: str, index_name):
    # Required functions to run at the only beginning
    self.index_name = index_name
    self.path = path
    self.raw_texts = text_embeddings(self.path, self.index_name)
  def extract_answer(self, query):
    # Get the similar text from the text and pass it to OpenAI
    self.embeddings = Pinecone.from_existing_index(self.index_name, HuggingFaceEmbeddings())
    docs = self.embeddings.similarity_search(query, k=1)
    give_answer(docs, query)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
path = "/content/drive/MyDrive/sample/The_Magic_of_Ayurveda.pdf"  #@param {type:"string"}
index_name = "ayurved"  #@param {type:"string"}
cb = ChatBot(path, index_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#@title get answer from support bot
query = "What is Acne?"  #@param {type:"string"}
cb.extract_answer(query)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-28-0c0dd6d6d920> in <module>
#       1 #@title get answer from support bot
#       2 query = "What is Acne?"  #@param {type:"string"}
# ----> 3 cb.extract_answer(query)
#
# <ipython-input-14-fd97ef95f514> in extract_answer(self, query)
#      10     # Get the similar text from the text and pass it to OpenAI
#      11     self.embeddings = Pinecone.from_existing_index(self.index_name, OpenAIEmbeddings())
# ---> 12     docs = self.embeddings.similarity_search(query, k=1)
#      13     give_answer(docs, query)
#
# /usr/local/lib/python3.8/dist-packages/langchain/vectorstores/pinecone.py in similarity_search(self, query, k, filter, namespace, **kwargs)
#     136         query_obj = self._embedding_function(query)
#     137         docs = []
# --> 138         results = self._index.query(
#     139             [query_obj],
#     140             top_k=k,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/utils/error_handling.py in inner_func(*args, **kwargs)
#      15         Config.validate()  # raises exceptions in case of invalid config
#      16         try:
# ---> 17             return func(*args, **kwargs)
#      18         except MaxRetryError as e:
#      19             if isinstance(e.reason, ProtocolError):
#
# /usr/local/lib/python3.8/dist-packages/pinecone/index.py in query(self, vector, id, queries, top_k, namespace, filter, include_values, include_metadata, **kwargs)
#     325             raise ValueError(f"Invalid query vector value passed: cannot interpret type {type(item)}")
#     326
# --> 327         response = self._vector_api.query(
#     328             QueryRequest(
#     329                 **args_dict,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in __call__(self, *args, **kwargs)
#     774
#     775         """
# --> 776         return self.callable(self, *args, **kwargs)
#     777
#     778     def call_with_http_info(self, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api/vector_operations_api.py in __query(self, query_request, **kwargs)
#     714             kwargs['query_request'] = \
#     715                 query_request
# --> 716             return self.call_with_http_info(**kwargs)
#     717
#     718         self.query = _Endpoint(
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in call_with_http_info(self, **kwargs)
#     836             params['header']['Content-Type'] = header_list
#     837
# --> 838         return self.api_client.call_api(
#     839             self.settings['endpoint_path'], self.settings['http_method'],
#     840             params['path'],
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     411         """
#     412         if not async_req:
# --> 413             return self.__call_api(resource_path, method,
#     414                                    path_params, query_params, header_params,
#     415                                    body, post_params, files,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     205         except ApiException as e:
#     206             e.body = e.body.decode('utf-8')
# --> 207             raise e
#     208
#     209         self.last_response = response_data
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     198         try:
#     199             # perform request and return response
# --> 200             response_data = self.request(
#     201                 method, url, query_params=query_params, headers=header_params,
#     202                 post_params=post_params, body=body,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     457                                             body=body)
#     458         elif method == "POST":
# --> 459             return self.rest_client.POST(url,
#     460                                          query_params=query_params,
#     461                                          headers=headers,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     269     def POST(self, url, headers=None, query_params=None, post_params=None,
#     270              body=None, _preload_content=True, _request_timeout=None):
# --> 271         return self.request("POST", url,
#     272                             headers=headers,
#     273                             query_params=query_params,
#
# /usr/local/lib/python3.8/dist-packages/pinecone/core/client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     228                 raise ServiceException(http_resp=r)
#     229
# --> 230             raise ApiException(http_resp=r)
#     231
#     232         return r
#
# ApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'content-type': 'application/json', 'date': 'Sat, 04 Feb 2023 13:40:10 GMT', 'x-envoy-upstream-service-time': '1', 'content-length': '109', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Query vector dimension 1536 does not match the dimension of the index 768","details":[]}
